# %% [markdown]
# ## Final Project: Phase 2
# Spring 2024
# Group: Michael Massone and Joseph Nelson Farrell
# DS 5230 Unsupervised Machine Learning
# Professor Steven Morin, PhD
# Due: 03/11/2024
# ___

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import os
import sys
from pathlib import Path
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ___
#
# ### Define File Paths

# %%
# define path
nb_path = Path(os.getcwd())
print(nb_path)
path = str(nb_path.parent)
print(path)

# path to figs folder
figs_path = path + '/figs'

# path to data
data_path= path + '/data'

# path to src folder
src_path = path + '/src'
print(src_path)

# sys path
sys.path.append(src_path)
# Out:
# /Users/nelsonfarrell/Documents/Northeastern/5230/final_project/DS5230-final/notebooks
# /Users/nelsonfarrell/Documents/Northeastern/5230/final_project/DS5230-final
# /Users/nelsonfarrell/Documents/Northeastern/5230/final_project/DS5230-final/src

# %% [markdown]
# ___
#
# ### Functions

# %%
from missingness_filter import missingness_cols
from ml_attributes import column_dtypes

# %% [markdown]
# ___
#
# ### Parameters

# %%
# design matrix csv file name
design_matrix_file_name = "/curated/beans_design.csv"

# missingness threshold for determining columns to drop
missingness_threshold = 0.20

# %% [markdown]
# ___
#
# ### Load Data

# %%
# read in design matrix
design_df = pd.read_csv( data_path + design_matrix_file_name)

# %% [markdown]
# ___
#
# ### Identify Columns with Missing Value Count Above Threshold

# %%
# check columns for missingness
cols_to_drop_list = missingness_cols(design_df, missingness_threshold)

# display results
if cols_to_drop_list == []:
    print(f'There are no columns that require dropping based on missingness')
else:
    print(f'The following columns have a missingness proportion greater than {missingness_threshold}.')
    print(f'These columns should be dropped:')
    for i in range(len(cols_to_drop_list)):
        print(f'\t{i + 1}. {cols_to_drop_list[i]}')
# Out:
# There are no columns that require dropping based on missingness

# %%
# get nominal and numerical columns, print column dtype
nominal_cols, numerical_cols = column_dtypes(design_df)

# display results
if nominal_cols == []:
    print(f'There no nominal columns in the dataset.\n')
else:
    print(f'The nominal columns are:')
    for i in range(len(nominal_cols)):
        print(f'{i + 1}: {nominal_cols[i]}')

if numerical_cols == []:
    print(f'There no numerical columns in the dataset.')
else:
    print(f'The numerical columns are:')
    for i in range(len(numerical_cols)):
        print(f'\t{i + 1}: {numerical_cols[i]}')
# Out:
# ********************************************************
#
# The column: Unnamed: 0 is data type int64
# The column: id is data type int64
# The column: Area is data type float64
# The column: Perimeter is data type float64
# The column: MajorAxisLength is data type float64
# The column: MinorAxisLength is data type float64
# The column: AspectRation is data type float64
# The column: Eccentricity is data type float64
# The column: ConvexArea is data type float64
# The column: EquivDiameter is data type float64
# The column: Extent is data type float64
# The column: Solidity is data type float64
# The column: roundness is data type float64
# The column: Compactness is data type float64
# The column: ShapeFactor1 is data type float64
# The column: ShapeFactor2 is data type float64
# The column: ShapeFactor3 is data type float64
# The column: ShapeFactor4 is data type float64
# ********************************************************
#
# There no nominal columns in the dataset.
#
# The numerical columns are:
# 	1: Unnamed: 0
# 	2: id
# 	3: Area
# 	4: Perimeter
# 	5: MajorAxisLength
# 	6: MinorAxisLength
# 	7: AspectRation
# 	8: Eccentricity
# 	9: ConvexArea
# 	10: EquivDiameter
# 	11: Extent
# 	12: Solidity
# 	13: roundness
# 	14: Compactness
# 	15: ShapeFactor1
# 	16: ShapeFactor2
# 	17: ShapeFactor3
# 	18: ShapeFactor4

# %%
design_df
# Out:
#        Unnamed: 0     id     Area  Perimeter  MajorAxisLength  \
# 0               0      0  28395.0    610.291       208.178117
# 1               1      1  28734.0    638.018       200.524796
# 2               2      2  29380.0    624.110       212.826130
# 3               3      3  30008.0    645.884       210.557999
# 4               4      4  30140.0    620.134       201.847882
# ...           ...    ...      ...        ...              ...
# 13606       13606  13606  42097.0    759.696       288.721612
# 13607       13607  13607  42101.0    757.499       281.576392
# 13608       13608  13608  42139.0    759.321       281.539928
# 13609       13609  13609  42147.0    763.779       283.382636
# 13610       13610  13610  42159.0    772.237       295.142741
#
#        MinorAxisLength  AspectRation  Eccentricity  ConvexArea  EquivDiameter  \
# 0           173.888747      1.197191      0.549812     28715.0     190.141097
# 1           182.734419      1.097356      0.411785     29172.0     191.272750
# 2           175.931143      1.209713      0.562727     29690.0     193.410904
# 3           182.516516      1.153638      0.498616     30724.0     195.467062
# 4           190.279279      1.060798      0.333680     30417.0     195.896503
# ...                ...           ...           ...         ...            ...
# 13606       185.944705      1.552728      0.765002     42508.0     231.515799
# 13607       190.713136      1.476439      0.735702     42494.0     231.526798
# 13608       191.187979      1.472582      0.734065     42569.0     231.631261
# 13609       190.275731      1.489326      0.741055     42667.0     231.653248
# 13610       182.204716      1.619841      0.786693     42600.0     231.686223
#
#          Extent  Solidity  roundness  Compactness  ShapeFactor1  ShapeFactor2  \
# 0      0.763923  0.988856   0.958027     0.913358      0.007332      0.003147
# 1      0.783968  0.984986   0.887034     0.953861      0.006979      0.003564
# 2      0.778113  0.989559   0.947849     0.908774      0.007244      0.003048
# 3      0.782681  0.976696   0.903936     0.928329      0.007017      0.003215
# 4      0.773098  0.990893   0.984877     0.970516      0.006697      0.003665
# ...         ...       ...        ...          ...           ...           ...
# 13606  0.714574  0.990331   0.916603     0.801865      0.006858      0.001749
# 13607  0.799943  0.990752   0.922015     0.822252      0.006688      0.001886
# 13608  0.729932  0.989899   0.918424     0.822730      0.006681      0.001888
# 13609  0.705389  0.987813   0.907906     0.817457      0.006724      0.001852
# 13610  0.788962  0.989648   0.888380     0.784997      0.007001      0.001640
#
#        ShapeFactor3  ShapeFactor4
# 0          0.834222      0.998724
# 1          0.909851      0.998430
# 2          0.825871      0.999066
# 3          0.861794      0.994199
# 4          0.941900      0.999166
# ...             ...           ...
# 13606      0.642988      0.998385
# 13607      0.676099      0.998219
# 13608      0.676884      0.996767
# 13609      0.668237      0.995222
# 13610      0.616221      0.998180
#
# [13611 rows x 18 columns]
